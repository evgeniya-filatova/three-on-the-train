# %%
import folium
import json
from folium.plugins import Fullscreen

# Загрузить данные из файла GeoJSON
with open('train.geojson', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Создать объект карты с подложкой Positron
m = folium.Map(tiles='CartoDB positron')

# Добавить кнопку полноэкранного режима
Fullscreen(position='topright').add_to(m)

# Функция для настройки стиля линейных объектов
def style_function(feature):
    return {
        'color': feature['properties'].get('stroke', '#3388ff'),
        'weight': feature['properties'].get('stroke-width', 5),
        'opacity': feature['properties'].get('stroke-opacity', 0.9)
    }

# Функция для настройки точечных объектов как маленьких точек
def marker_function(feature):
    folium.CircleMarker(
        location=[feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]],
        radius=3,
        color=feature['properties'].get('marker-color', '#3388ff'),
        fill=True,
        fill_color=feature['properties'].get('marker-color', '#3388ff'),
        fill_opacity=1.0,
        popup=feature['properties'].get('description', 'No description')
    ).add_to(m)

# Добавить объекты на карту
bounds = []
for feature in data['features']:
    if feature['geometry']['type'] == 'LineString':
        folium.GeoJson(
            feature,
            style_function=style_function
        ).add_to(m)
        for coord in feature['geometry']['coordinates']:
            bounds.append([coord[1], coord[0]])
    elif feature['geometry']['type'] == 'Point':
        marker_function(feature)
        bounds.append([feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]])

# Автоматическое масштабирование карты
if bounds:
    m.fit_bounds(bounds)

# Сохранить карту в HTML-файл
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db93a275f1e5df47a367c507af3fda19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db93a275f1e5df47a367c507af3fda19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db93a275f1e5df47a367c507af3fda19 = L.map(
#                 &quot;map_db93a275f1e5df47a367c507af3fda19&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb123ea52896f322a27f9ca6c7611d08 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_eb123ea52896f322a27f9ca6c7611d08.addTo(map_db93a275f1e5df47a367c507af3fda19);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_db93a275f1e5df47a367c507af3fda19);
#
#
#         function geo_json_f95480435682a236b623a6dbb6aa4cc9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0e4779&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_f95480435682a236b623a6dbb6aa4cc9_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f95480435682a236b623a6dbb6aa4cc9 = L.geoJson(null, {
#                 onEachFeature: geo_json_f95480435682a236b623a6dbb6aa4cc9_onEachFeature,
#
#                 style: geo_json_f95480435682a236b623a6dbb6aa4cc9_styler,
#         });
#
#         function geo_json_f95480435682a236b623a6dbb6aa4cc9_add (data) {
#             geo_json_f95480435682a236b623a6dbb6aa4cc9
#                 .addData(data);
#         }
#             geo_json_f95480435682a236b623a6dbb6aa4cc9_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[103.83615851263343, 52.5083742880758], [103.84444117407143, 52.50504861042599], [103.85190844396891, 52.50151316398625], [103.85753035406414, 52.498134581507166]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;description&quot;: &quot;\u0421\u043e\u0446\u0438\u0430\u043b\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0430\u044f, \u043c\u043e\u0437\u0430\u0438\u043a\u0430\n&quot;, &quot;stroke&quot;: &quot;#0e4779&quot;, &quot;stroke-opacity&quot;: 0.9, &quot;stroke-width&quot;: &quot;5&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_f95480435682a236b623a6dbb6aa4cc9.addTo(map_db93a275f1e5df47a367c507af3fda19);
#
#
#         function geo_json_86159abe91d7bb29d118ce51f3ce780b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1e98ff&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_86159abe91d7bb29d118ce51f3ce780b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_86159abe91d7bb29d118ce51f3ce780b = L.geoJson(null, {
#                 onEachFeature: geo_json_86159abe91d7bb29d118ce51f3ce780b_onEachFeature,
#
#                 style: geo_json_86159abe91d7bb29d118ce51f3ce780b_styler,
#         });
#
#         function geo_json_86159abe91d7bb29d118ce51f3ce780b_add (data) {
#             geo_json_86159abe91d7bb29d118ce51f3ce780b
#                 .addData(data);
#         }
#             geo_json_86159abe91d7bb29d118ce51f3ce780b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[104.27756227002213, 52.27580073070849], [104.28186989769992, 52.27940045702896], [104.28252435669954, 52.279926900598824], [104.28106529193435, 52.282164428238694], [104.27756769137895, 52.28125635523348], [104.28100091891804, 52.2821973290827], [104.28073269801646, 52.2843489910214], [104.28066832500014, 52.28587548871822], [104.27843672709969, 52.28526358004021], [104.28058249431157, 52.28598076247204], [104.2803464599182, 52.28659924070392], [104.28002459483642, 52.287151916038646], [104.2807112403442, 52.287796695171615], [104.28064686732783, 52.29002703188257], [104.28211671786804, 52.29039545422491], [104.28133887725365, 52.291046764759024], [104.28028745131981, 52.2909184770814], [104.28150517421251,

# %%
import folium
import json
from folium.plugins import Fullscreen

# Загрузить данные из файла GeoJSON
with open('train.geojson', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Создать объект карты с кастомной подложкой (Яндекс карты)
m = folium.Map(tiles=None)

# Добавить подложку Яндекс карты
folium.TileLayer(
    tiles='https://core-renderer-tiles.maps.yandex.net/tiles?l=map&v=22.06.16-0&x={x}&y={y}&z={z}&scale=1&lang=ru_RU',
    attr='Yandex',
    name='Yandex Maps',
    max_zoom=19,
    min_zoom=1
).add_to(m)

# Добавить кнопку полноэкранного режима
Fullscreen(position='topright').add_to(m)

# Функция для настройки стиля линейных объектов
def style_function(feature):
    return {
        'color': feature['properties'].get('stroke', '#3388ff'),
        'weight': feature['properties'].get('stroke-width', 5),
        'opacity': feature['properties'].get('stroke-opacity', 0.9)
    }

# Функция для настройки точечных объектов как маленьких точек с надписью
def marker_function(feature):
    popup_text = feature['properties'].get('description', 'No description')
    icon_caption = feature['properties'].get('iconCaption', None)
    if icon_caption:
        popup_text = icon_caption
    folium.CircleMarker(
        location=[feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]],
        radius=3,
        color=feature['properties'].get('marker-color', '#3388ff'),
        fill=True,
        fill_color=feature['properties'].get('marker-color', '#3388ff'),
        fill_opacity=1.0,
        popup=popup_text
    ).add_to(m)

# Добавить объекты на карту
bounds = []
for feature in data['features']:
    if feature['geometry']['type'] == 'LineString':
        folium.GeoJson(
            feature,
            style_function=style_function
        ).add_to(m)
        for coord in feature['geometry']['coordinates']:
            bounds.append([coord[1], coord[0]])
    elif feature['geometry']['type'] == 'Point':
        marker_function(feature)
        bounds.append([feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]])

# Автоматическое масштабирование карты
if bounds:
    m.fit_bounds(bounds)

# Сохранить карту в HTML-файл
#m.save('map.html')

# %%
import folium
import json
from folium.plugins import Fullscreen

# Загрузить данные из файла GeoJSON
with open('train.geojson', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Создать объект карты с подложкой OSM
m = folium.Map(tiles="OpenStreetMap")

# Добавить кнопку полноэкранного режима
Fullscreen(position='topright').add_to(m)

# Функция для настройки стиля линейных объектов
def style_function(feature):
    return {
        'color': feature['properties'].get('stroke', '#3388ff'),
        'weight': feature['properties'].get('stroke-width', 5),
        'opacity': feature['properties'].get('stroke-opacity', 0.9)
    }

# Функция для настройки точечных объектов как маленьких точек с надписью
def marker_function(feature):
    popup_text = feature['properties'].get('description', 'No description')
    icon_caption = feature['properties'].get('iconCaption', None)
    if icon_caption:
        folium.map.Marker(
            [feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]],
            icon=folium.DivIcon(
                icon_size=(150, 36),
                icon_anchor=(0, 0),
                html=f'<div style="font-size: 12pt; color: black;">{icon_caption}</div>'
            )
        ).add_to(m)
    folium.CircleMarker(
        location=[feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]],
        radius=3,
        color=feature['properties'].get('marker-color', '#3388ff'),
        fill=True,
        fill_color=feature['properties'].get('marker-color', '#3388ff'),
        fill_opacity=1.0,
        popup=popup_text
    ).add_to(m)

# Добавить объекты на карту
bounds = []
for feature in data['features']:
    if feature['geometry']['type'] == 'LineString':
        folium.GeoJson(
            feature,
            style_function=style_function
        ).add_to(m)
        for coord in feature['geometry']['coordinates']:
            bounds.append([coord[1], coord[0]])
    elif feature['geometry']['type'] == 'Point':
        marker_function(feature)
        bounds.append([feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]])

# Автоматическое масштабирование карты
if bounds:
    m.fit_bounds(bounds)

# Сохранить карту в HTML-файл
#m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2ad44398631094b10695c86281d75c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2ad44398631094b10695c86281d75c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2ad44398631094b10695c86281d75c0 = L.map(
#                 &quot;map_c2ad44398631094b10695c86281d75c0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74dd701c120a73aa21fa874e3464af4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_74dd701c120a73aa21fa874e3464af4a.addTo(map_c2ad44398631094b10695c86281d75c0);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_c2ad44398631094b10695c86281d75c0);
#
#
#         function geo_json_5260235c2b78de1fe887e34c328b542f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#82cdff&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_5260235c2b78de1fe887e34c328b542f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_5260235c2b78de1fe887e34c328b542f = L.geoJson(null, {
#                 onEachFeature: geo_json_5260235c2b78de1fe887e34c328b542f_onEachFeature,
#
#                 style: geo_json_5260235c2b78de1fe887e34c328b542f_styler,
#         });
#
#         function geo_json_5260235c2b78de1fe887e34c328b542f_add (data) {
#             geo_json_5260235c2b78de1fe887e34c328b542f
#                 .addData(data);
#         }
#             geo_json_5260235c2b78de1fe887e34c328b542f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[103.83615851263343, 52.5083742880758], [103.84444117407143, 52.50504861042599], [103.85190844396891, 52.50151316398625], [103.85753035406414, 52.498134581507166]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;description&quot;: &quot;\u0421\u043e\u0446\u0438\u0430\u043b\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0430\u044f, \u043c\u043e\u0437\u0430\u0438\u043a\u0430\n&quot;, &quot;stroke&quot;: &quot;#82cdff&quot;, &quot;stroke-opacity&quot;: 0.9, &quot;stroke-width&quot;: &quot;5&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_5260235c2b78de1fe887e34c328b542f.addTo(map_c2ad44398631094b10695c86281d75c0);
#
#
#         function geo_json_f520ba2f2c4b8e1e0949de0fb01df472_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1e98ff&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_f520ba2f2c4b8e1e0949de0fb01df472_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f520ba2f2c4b8e1e0949de0fb01df472 = L.geoJson(null, {
#                 onEachFeature: geo_json_f520ba2f2c4b8e1e0949de0fb01df472_onEachFeature,
#
#                 style: geo_json_f520ba2f2c4b8e1e0949de0fb01df472_styler,
#         });
#
#         function geo_json_f520ba2f2c4b8e1e0949de0fb01df472_add (data) {
#             geo_json_f520ba2f2c4b8e1e0949de0fb01df472
#                 .addData(data);
#         }
#             geo_json_f520ba2f2c4b8e1e0949de0fb01df472_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[104.27756227002213, 52.27580073070849], [104.28186989769992, 52.27940045702896], [104.28252435669954, 52.279926900598824], [104.28106529193435, 52.282164428238694], [104.27756769137895, 52.28125635523348], [104.28100091891804, 52.2821973290827], [104.28073269801646, 52.2843489910214], [104.28066832500014, 52.28587548871822], [104.27843672709969, 52.28526358004021], [104.28058249431157, 52.28598076247204], [104.2803464599182, 52.28659924070392], [104.28002459483642, 52.287151916038646], [104.2807112403442, 52.287796695171615], [104.28064686732783, 52.29002703188257], [104.28211671786804, 52.29039545422491], [104.28133887725365, 52.291046764759024], [104.28028745131981, 52.2909184770814], [104.28150517421251, 52.29217173301439], [104.28208453135977, 52.29241514341905], [104.28622586207875, 52.293382193101046], [104.287

# %%
import folium
import json
from folium.plugins import Fullscreen

# Загрузить данные из файла GeoJSON
try:
    with open('train.geojson', 'r', encoding='utf-8') as file:
        data = json.load(file)
except (FileNotFoundError, json.JSONDecodeError) as e:
    print(f"Error loading GeoJSON file: {e}")
    data = {"features": []}

# Создать объект карты с подложкой OSM
m = folium.Map(tiles="OpenStreetMap")

# Добавить кнопку полноэкранного режима
Fullscreen(position='topright').add_to(m)

# Функция для настройки стиля линейных объектов
def style_function(feature):
    return {
        'color': feature['properties'].get('stroke', '#3388ff'),
        'weight': feature['properties'].get('stroke-width', 5),
        'opacity': feature['properties'].get('stroke-opacity', 0.9)
    }

# Функция для настройки точечных объектов как маленьких точек с надписью
def marker_function(feature):
    popup_text = feature['properties'].get('description', 'No description')
    icon_caption = feature['properties'].get('iconCaption', None)
    if icon_caption:
        popup_text = icon_caption
    folium.CircleMarker(
        location=[feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]],
        radius=3,
        color=feature['properties'].get('marker-color', '#3388ff'),
        fill=True,
        fill_color=feature['properties'].get('marker-color', '#3388ff'),
        fill_opacity=1.0,
        popup=popup_text
    ).add_to(m)

# Добавить объекты на карту
bounds = []
for feature in data['features']:
    if feature['geometry']['type'] == 'LineString':
        folium.GeoJson(
            feature,
            style_function=style_function
        ).add_to(m)
        for coord in feature['geometry']['coordinates']:
            bounds.append([coord[1], coord[0]])
    elif feature['geometry']['type'] == 'Point':
        marker_function(feature)
        bounds.append([feature['geometry']['coordinates'][1], feature['geometry']['coordinates'][0]])

# Автоматическое масштабирование карты
if bounds:
    m.fit_bounds(bounds)

# Сохранить карту в HTML-файл
m.save('map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac0949b4f44f73cf899e734bdf22899 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac0949b4f44f73cf899e734bdf22899&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac0949b4f44f73cf899e734bdf22899 = L.map(
#                 &quot;map_bac0949b4f44f73cf899e734bdf22899&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9df21d3334b508a90bb2768a1e1890fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9df21d3334b508a90bb2768a1e1890fd.addTo(map_bac0949b4f44f73cf899e734bdf22899);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topright&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_bac0949b4f44f73cf899e734bdf22899);
#
#
#         function geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#0e4779&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7 = L.geoJson(null, {
#                 onEachFeature: geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_onEachFeature,
#
#                 style: geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_styler,
#         });
#
#         function geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_add (data) {
#             geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7
#                 .addData(data);
#         }
#             geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[103.83615851263343, 52.5083742880758], [103.84444117407143, 52.50504861042599], [103.85190844396891, 52.50151316398625], [103.85753035406414, 52.498134581507166]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: 0, &quot;properties&quot;: {&quot;description&quot;: &quot;\u0421\u043e\u0446\u0438\u0430\u043b\u0438\u0441\u0442\u0438\u0447\u0435\u0441\u043a\u0430\u044f, \u043c\u043e\u0437\u0430\u0438\u043a\u0430\n&quot;, &quot;stroke&quot;: &quot;#0e4779&quot;, &quot;stroke-opacity&quot;: 0.9, &quot;stroke-width&quot;: &quot;5&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_eca9d6ad241b1ee3859c4f413c4c8bc7.addTo(map_bac0949b4f44f73cf899e734bdf22899);
#
#
#         function geo_json_8a65208d1d806d276b7f10e28016cef1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#1e98ff&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: &quot;5&quot;};
#             }
#         }
#
#         function geo_json_8a65208d1d806d276b7f10e28016cef1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8a65208d1d806d276b7f10e28016cef1 = L.geoJson(null, {
#                 onEachFeature: geo_json_8a65208d1d806d276b7f10e28016cef1_onEachFeature,
#
#                 style: geo_json_8a65208d1d806d276b7f10e28016cef1_styler,
#         });
#
#         function geo_json_8a65208d1d806d276b7f10e28016cef1_add (data) {
#             geo_json_8a65208d1d806d276b7f10e28016cef1
#                 .addData(data);
#         }
#             geo_json_8a65208d1d806d276b7f10e28016cef1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[104.27756227002213, 52.27580073070849], [104.28186989769992, 52.27940045702896], [104.28252435669954, 52.279926900598824], [104.28106529193435, 52.282164428238694], [104.27756769137895, 52.28125635523348], [104.28100091891804, 52.2821973290827], [104.28073269801646, 52.2843489910214], [104.28066832500014, 52.28587548871822], [104.27843672709969, 52.28526358004021], [104.28058249431157, 52.28598076247204], [104.2803464599182, 52.28659924070392], [104.28002459483642, 52.287151916038646], [104.2807112403442, 52.287796695171615], [104.28064686732783, 52.29002703188257], [104.28211671786804, 52.29039545422491], [104.28133887725365, 52.291046764759024], [104.28028745131981, 52.2909184770814], [104.28150517421251, 52.29217173301439], [104.28208453135977, 52.29241514341905], [104.28622586207875, 52.293382193101046], [104.287
